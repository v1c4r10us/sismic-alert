# %% [markdown]
# # SELENIUM fue la que me extrae el DOM pero requiere un navegador instalado y sería cuestion de probarlo en una plataforma de despliegue como render o railway

# %% [markdown]
# + Revisar si es suficiente con los datos extraidos directamente
# + Caso contrario Ver la forma de extraer y limpiar las url de la tabla de sismos para tener mas información (hipocentro, profundidad, latitud, longitud, etc)

# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import time

chrome_options = Options()
chrome_options.add_argument("--headless")
# Configurar el controlador del navegador
driver = webdriver.Firefox(options=chrome_options)  # Cambia a webdriver.Firefox() si prefieres Firefox

# Navegar a la página web
driver.get("https://www.data.jma.go.jp/multi/quake/index.html?lang=es") #Url de la pagina de japon
time.sleep(10)

# Obtener el contenido del DOM
dom = driver.page_source

# Imprimir el DOM
print(dom)

# Cerrar el navegador
driver.quit()
# Out:
# <html lang="ja"><head>
#     <meta charset="utf-8">
#     <meta name="description" content="気象庁">
#     <meta name="keywords" content="気象庁">
#     <meta name="viewport" content="width=device-width,user-scalable=yes,maximum-scale=2">
#     <meta name="format-detection" content="telephone=no">
#     <link rel="icon" href="../favicon.ico">
#     <link rel="apple-touch-icon" sizes="57x57" href="../apple-touch-icon.png">
#     <link href="../css/normalize.css" type="text/css" rel="stylesheet">
#     <link href="../css/layout.css" type="text/css" rel="stylesheet">
#     <link href="../css/layout_sp.css" type="text/css" rel="stylesheet">
#     <link href="../css/quake.css" type="text/css" rel="stylesheet">
#     <title>Agencia Meteorológica de Japón | Información de terremoto</title>
# </head>
#
# <body>
# <div class="wrap">
#
# <header>
# <div class="inner">
# <h1><img id="icon_jma" src="../images/common/logo.gif" alt="Agencia Meteorológica de Japón"></h1>
# <div class="language_select">
# <div id="language_select_label" class="language_select_label">Elegir idioma</div>
# <form>
# <select name="language_select" id="language_select" onchange="onChangeLanguage(value)" style="height: 24px;">
# 	<option value="jp">日本語</option>
# 	<option value="en">English</option>
# 	<option value="cn_zs">简体中文</option>
# 	<option value="cn_zt">繁體中文</option>
# 	<option value="kr">한국어</option>
# 	<option value="es">Español</option>
# 	<option value="pt">Português</option>
# 	<option value="id">Bahasa Indonesia</option>
# 	<option value="vn">Tiếng Việt</option>
# 	<option value="ph">Tagalog</option>
# 	<option value="th">ภาษาไทย</option>
# 	<option value="np">नेपाली भाषा</option>
#   	<option value="kh">ភាសាខ្មែរ</option>
#   	<option value="mm">မြန်မာဘာသာစကား</option>
#   	<option value="mn">Монгол хэл</option>
# </select>
# </form>
# </div>
# </div>
# </header>
#
# <div id="globalMenuS"><!-- globalMenuS start-->
# <div id="top-head">
# <div id="mobile-head">
# <div id="nav-toggle">
#     <div id="menu_title" class="init-bottom">Información de terremoto</div>
# </div>
# </div>
# <nav id="global-nav">
# <ul>
# <li><a id="tab_home" href="https://www.data.jma.go.jp/multi/index.html?lang=es">Inicio</a></li>
# <li><a id="tab_warn" href="https://www.data.jma.go.jp/multi/warn/index.html?lang=es">Alerta・Advertencia meteorológica</a></li>
# <li><a id="tab_yoho" href="https://www.data.jma.go.jp/multi/yoho/index.html?lang=es">Pronóstico de tiempo</a></li>
# <li><a id="tab_cyclon" href="https://www.data.jma.go.jp/multi/cyclone/index.html?lang=es">Información de Tifón</a></li>
# <li><a id="tab_cloud" target="_blank" href="https://www.jma.go.jp/bosai/multi_nowc/?lang=es">Desplazamiento de nubes de lluvia.</a></li>
# <li><a id="tab_kotan" target="_blank" href="https://www.jma.go.jp/bosai/multi_kaikotan/?lang=es">Lluvia desde ahora</a></li>
# <li><a id="tab_sub_landslide" target="_blank" href="https://www.jma.go.jp/bosai/multi_risk/?lang=es#elements:land">Mapa de riesgo de alertas : Desastre por deslizamiento de tierra</a>
# </li><li><a id="tab_sub_inundation" target="_blank" href="https://www.jma.go.jp/bosai/multi_risk/?lang=es#elements:inund">Mapa de riesgo de alertas : Daños por inundación</a>
# </li><li><a id="tab_sub_flood" target="_blank" href="https://www.jma.go.jp/bosai/multi_risk/?lang=es#elements:flood">Mapa de riesgo de alertas : Inundación</a>
# </li><li><a id="tab_tsunami" href="https://www.data.jma.go.jp/multi/tsunami/index.html?lang=es">Alerta・Advertencia de Tsunami</a></li>
# <li><a id="tab_quake" href="https://www.data.jma.go.jp/multi/quake/index.html?lang=es">Información de terremoto</a></li>
# <li><a id="tab_volcano" href="https://www.data.jma.go.jp/multi/volcano/index.html?lang=es">Alerta・Pronóstico de erupción</a></li>
# </ul>
# </nav>
# </div>
# </div><!-- globalMenuS end-->
#
# <main>
# <div class="inner">
# 	<div id="mente">
# 		<div id="mente-emoji"></div>
# 		<div id="mente-message"></div>
# 	</div>
#
# <div class="breadcrumb">
# <ul>
# <li><a id="breadcrumb_home" href="https://www.data.jma.go.jp/multi/index.html?lang=es">Inicio</a></li>
# <li id="breadcrumb_quake_list">Información de terremoto</li>
# </ul>
# </div>
#
# <section class="quake_contents">
#
# <h1 id="header">Información de terremoto</h1>
#
# <h2 id="sub_header">Información de terremoto Lista</h2>
#
# <div class="quakelevel_link">
# <a id="quake_advisory_link" href="https://www.data.jma.go.jp/multi/quake/quake_advisory.html?lang=es">Explicación sobre intensidad sísmica</a>
# </div>
#
# <table id="quakeindex_table" class="quakeindex_table" width="100%" cellspacing="0" cellpadding="0" border="0">
# 	<tbody>
# 		<tr>
# 			<th id="quaketable_col01" scope="col" class="quaketable_col01">Hora y día cuando fue detectado el terremoto</th>
# 			<th id="quaketable_col02" scope="col" class="quaketable_col02">Lugar del epicentro</th>
# 			<th id="quaketable_col03" scope="col" class="quaketable_col03">Magnitud</th>
# 			<th id="quaketable_col04" scope="col" class="quaketable_col04">La mayor intensidad sísmica</th>
# 			<th id="quaketable_col05" scope="col" class="quaketable_col05">Hora y día de la emisión</th>
# 		</tr>
Alta mar de Uraga</td><td>4.3</td><td>2</td><td>2023/04/30 18:03</td></tr><tr><td><a href="quake_detail.html?eventID=20230501085553&amp;lang=es">2023/04/30 17:51</a></td><td>Alta mar de Prefectura de Ibaraki</td><td>4.3</td><td>2</td><td>2023/04/30 17:55</td></tr><tr><td><a href="quake_detail.html?eventID=20230501071823&amp;lang=es">2023/04/30 16:15</a></td><td>Norte de Prefectura de Tokushima</td><td>3.4</td><td>2</td><td>2023/04/30 16:18</td></tr><tr><td><a href="quake_detail.html?eventID=20230501050835&amp;lang=es">2023/04/30 14:04</a></td><td>Alta mar de Prefectura de Ibaraki</td><td>4.2</td><td>3</td><td>2023/04/30 14:08</td></tr><tr><td><a href="quake_detail.html?eventID=20230501050353&amp;lang=es">2023/04/30 13:58</a></td><td>Mares cercanos de Isla Chichishima</td><td>3.8</td><td>1</td><td>2023/04/30 14:03</td></tr><tr><td><a href="quake_detail.html?eventID=20230501014007&amp;lang=es">2023/04/30 10:37</a></td><td>Mares cercanos de Islas de Amamioshima</td><td>3.3</td><td>2</td><td>2023/04/3 ...
# </table>
#
#
#
#
# </section>
#
# </div>
# </main>
#
# <div id="pagetop" style="display: none;"><a href="#top">topへ</a></div>
#
# <footer><!-- footer -->
# <div class="inner">
# <p id="copyright" class="copyright">Agencia Meteorológica de Japón : 3-6-9 Toranomon, Minato City, Tokyo 105-8431, Japan</p>
# </div>
# </footer>
# <!-- /footer -->
#
#
# <script src="../js/jquery.min.js"></script>
# <script src="../js/util.js"></script>
# <script src="../js/common.js"></script>
# <script src="../js/quake_list.js"></script>
# <script src="../js/mente_message.js"></script>
# <script>
# write_error_message("../data/VXSE53/warning.json", "#mente-emoji", "#mente-message");
# </script>
#
# </div>
#
#
# </body></html>

# %% [markdown]
# # Esta es otra Libreria llamanda SCRAPY pero lo probé y no me funcionó :(

# %%
SPLASH_URL = 'https://www.data.jma.go.jp/multi/quake/index.html?lang=es'
DOWNLOADER_MIDDLEWARES = {
    'scrapy_splash.SplashCookiesMiddleware': 723,
    'scrapy_splash.SplashMiddleware': 725,
    'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware': 810,
}

# %%
import scrapy
from scrapy_splash import SplashRequest

class MySpider(scrapy.Spider):
    name = 'my_spider'

    def start_requests(self):
        url = 'https://www.data.jma.go.jp/multi/quake/index.html?lang=es'
        yield SplashRequest(url, self.parse, args={'wait': 10})

    def parse(self, response):
        # Obtener el contenido del DOM
        dom = response.text
        print(dom)
        # Trabajar con el DOM
        # ...
x=MySpider()
x.parse(x)
        # Continuar con el procesamiento de los datos
        # ...
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5116/1699820681.py in <module>
#      16         # ...
#      17 x=MySpider()
# ---> 18 x.parse(x)
#      19         # Continuar con el procesamiento de los datos
#      20         # ...
#
# /tmp/ipykernel_5116/1699820681.py in parse(self, response)
#      11     def parse(self, response):
#      12         # Obtener el contenido del DOM
# ---> 13         dom = response.text
#      14         print(dom)
#      15         # Trabajar con el DOM
#
# AttributeError: 'MySpider' object has no attribute 'text'
